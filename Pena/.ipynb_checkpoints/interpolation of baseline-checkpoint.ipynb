# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import NISTdata as nd
from scipy.interpolate import interp1d
import periodictable as pt
from IPython.html.widgets import interact, interactive
# Out:
# Populating the interactive namespace from numpy and matplotlib
# These are not the L-lines you are looking for

# %%
elements = ['Fe K-a', 'Fe K-b', 'Cu K-a', 'Cu K-b', 'Ni K-a', 'Ni K-b', 'Zn K-a', 'Zn K-b', \
            'Zr K-a', 'Zr K-b', 'Mo K-a', 'Mo K-b', 'Rh K-a', 'Rh K-b', 'Sn K-a', 'Sn K-b', \
            'Pb L-a', 'Pb L-b' ]
energy = np.array([6.40, 7.06, 8.05, 8.90, 7.48, 8.26, 8.64, 9.57, \
                15.77, 17.67, 17.48, 19.61, 20.21, 22.72, 25.27, 28.48, \
                10.55, 12.61])

channels = array([81.39, 89.71, 102.23, 113.13, 95.00, 104.95, 109.61, 133.84, 199.62, 224.12, 221.20, 248.51, 255.48, 287.66, 318.69, 359.88, 133.91, 160.27])

plot(channels,energy,"ro")
xlabel("Channel",fontsize=20)
ylabel("Energy (keV)",fontsize=20)

#Import the curve fitter from the scipy optimize package
from scipy.optimize import curve_fit

#Define the fit function
func = lambda x,m,b: m*x + b

# Make initial guess at parameters
p0 = [0.1, -0.05]

#Call the curve fitter with FWHM as standard weights
#and have it return the optimized parameters (popt) and covariance matrix (pcov)
popt,pcov = curve_fit(func,channels,energy,p0)

fitresult = func(channels,popt[0],popt[1])
print popt[0],popt[1]

plt.plot(channels,energy,"ro",label="Calibration data")
curve="Energy = %.2f*Channel + %.2f"%(popt[0],popt[1])
plt.plot(channels,fitresult,'b-',label=curve)
plt.xlabel("Channel Number",fontsize=20)
plt.ylabel("Energy (keV)",fontsize=20)
plt.legend(loc="best")
plt.plot()
# Out:
# 0.0796602014474 -0.183629140469
# []

# %%
data = np.loadtxt("../data/Pena-specimen-12Feb2014.txt")
norm = 1994.569 #amount of time the experiment was run

chan = np.arange(512)
calEn = chan*popt[0] + popt[1]#
#print calEn
cts = data/norm

# %%
'''
Here I find all local mins and define boundaries as horizontal lines of connecting to closest value.
I then interpolate the data so that it is defined at any point that we wish. This is so that it is defined at all energy values.
'''
low = [[],[]]
init = False
for en in xrange(2,511):
    if cts[en]<cts[en+1] and cts[en]<cts[en-1]:
        if init == False:
            low[0].append(calEn[0])
            low[1].append(cts[en])
            init = True
        low[0].append(calEn[en])
        low[1].append(cts[en])
low[0].append(calEn[-1])
low[1].append(low[1][-1])
print low
lowf = interp1d(low[0],low[1], kind="linear")
print lowf(0)
print calEn
# Out:
# [[-0.18362914046903228, 0.3739922696628209, 0.53331267255763604, 0.77229327689985894, 2.0468565000583805, 2.5248177087428263, 2.9231187159798639, 3.0824391188746794, 3.321419723216902, 3.7993809319013478, 3.9587013347961633, 4.1976819391383851, 4.7553033492702381, 4.9942839536124612, 5.3925849608494989, 5.950206370981352, 6.6671481840080205, 7.3044297955872812, 7.7823910042717275, 8.1010318100613592, 8.4196726158509883, 8.6586532201932123, 8.8976338245354345, 9.0569542274302499, 9.2162746303250653, 9.4552552346672876, 9.614575637562103, 10.012876644799141, 10.172197047693956, 10.411177652036178, 10.729818457825809, 11.128119465062847, 11.287439867957662, 11.446760270852478, 11.606080673747293, 11.845061278089515, 12.243362285326553, 13.03996429980063, 13.597585709932483, 14.314527522959152, 14.473847925853965, 14.792488731643596, 14.951809134538411, 15.350110141775449, 15.509430544670264, 15.66875094756508, 15.828071350459895, 16.465352962039155, 17.341615177960637, 18.377197796776937, 18.53651819967175, 18.934819206908788, 19.333120214145829, 19.731421221382867, 19.89074162427768, 20.129722228619904, 20.289042631514718, 20.528023235856942, 21.005984444541387, 21.165304847436204, 21.563605854673241, 21.722926257568055, 22.678848674936948, 22.838169077831761, 23.077149682173985, 23.395790487963616, 23.55511089085843, 23.714431293753247, 23.953411898095467, 24.272052703885098, 24.590693509674729, 24.988994516911767, 25.546615927043621, 25.705936329938435, 25.944916934280659, 26.821179150202141, 27.060159754544365, 27.219480157439179, 27.856761769018441, 28.095742373360665, 28.334722977702885, 28.812684186387333, 28.972004589282147, 29.210985193624371, 29.370305596519184, 29.609286200861408, 29.848266805203629, 30.007587208098446, 40.522733799156249], [0.019051734986355449, 0.019051734986355449, 0.020054457880374157, 0.029078963926542526, 0.57004796524963541, 0.6161732183744959, 0.62419500152664564, 0.60514326654029016, 0.62168819429159883, 0.59411331470608442, 0.61918138705655212, 0.62168819429159883, 0.74201494157384373, 0.67784067635664647, 0.780619772993564, 1.7392228596754487, 1.314569714058526, 0.70641827883617969, 0.28176513321925689, 0.32588494055608003, 0.24616847048159277, 0.20906772340290058, 0.19803777156869479, 0.18550373539346093, 0.17698059079430192, 0.1664520004071055, 0.17547650645327387, 0.14489345818570329, 0.14439209673869394, 0.15642477146691841, 0.1358689521395349, 0.15040843410280616, 0.154419325678881, 0.16093702449000261, 0.15792885580794649, 0.17547650645327387, 0.19954185590972284, 0.10027228940187079, 0.074702855604393728, 0.03760210852570154, 0.033089855502617359, 0.04261572299579508, 0.045122530230841854, 0.036098024184673484, 0.038103469972710899, 0.050136144700935394, 0.058659289300094411, 0.069187879687290843, 0.074201494157384376, 0.025068072350467697, 0.020555819327383509, 0.025569433797477049, 0.026572156691495756, 0.039106192866729603, 0.048632060359907331, 0.03760210852570154, 0.030081686820561233, 0.032087132608598648, 0.033089855502617359, 0.033089855502617359, 0.029078963926542526, 0.015040843410280617, 0.013536759069252556, 0.013536759069252556, 0.013536759069252556, 0.011029951834205786, 0.016544927751308679, 0.016043566304299324, 0.022059903668411571, 0.027073518138505111, 0.034593939843645422, 0.04762933746588862, 0.015040843410280617, 0.0095258674931777247, 0.012032674728224493, 0.008021783152149662, 0.017046289198318031, 0.020555819327383509, 0.0090245060461683711, 0.010027228940187078, 0.011029951834205786, 0.010528590387196432, 0.008021783152149662, 0.011029951834205786, 0.010027228940187078, 0.0075204217051403083, 0.011029951834205786, 0.011029951834205786, 0.011029951834205786]]
# 0.0190517349864
# [ -1.83629140e-01  -1.03968939e-01  -2.43087376e-02   5.53514639e-02
#    1.35011665e-01   2.14671867e-01   2.94332068e-01   3.73992270e-01
#    4.53652471e-01   5.33312673e-01   6.12972874e-01   6.92633075e-01
#    7.72293277e-01   8.51953478e-01   9.31613680e-01   1.01127388e+00
#    1.09093408e+00   1.17059428e+00   1.25025449e+00   1.32991469e+00
#    1.40957489e+00   1.48923509e+00   1.56889529e+00   1.64855549e+00
#    1.72821569e+00   1.80787590e+00   1.88753610e+00   1.96719630e+00
#    2.04685650e+00   2.12651670e+00   2.20617690e+00   2.28583710e+00
#    2.36549731e+00   2.44515751e+00   2.52481771e+00   2.60447791e+00
#    2.68413811e+00   2.76379831e+00   2.84345851e+00   2.92311872e+00
#    3.00277892e+00   3.08243912e+00   3.16209932e+00   3.24175952e+00
#    3.32141972e+00   3.40107992e+00   3.48074013e+00   3.56040033e+00
#    3.64006053e+00   3.71972073e+00   3.79938093e+00   3.87904113e+00
#    3.95870133e+00   4.03836154e+00   4.11802174e+00   4.19768194e+00
#    4.27734214e+00   4.35700234e+00   4.43666254e+00   4.51632274e+00
#    4.59598295e+00   4.67564315e+00   4.75530335e+00   4.83496355e+00
#    4.91462375e+00   4.99428395e+00   5.07394416e+00   5.15360436e+00
#    5.23326456e+00   5.31292476e+00   5.39258496e+00   5.47224516e+00
#    5.55190536e+00   5.63156557e+00   5.71122577e+00   5.79088597e+00
#    5.87054617e+00   5.95020637e+00   6.02986657e+00   6.10952677e+00
#    6.18918698e+00   6.26884718e+00   6.34850738e+00   6.42816758e+00
#    6.50782778e+00   6.58748798e+00   6.66714818e+00   6.74680839e+00
#    6.82646859e+00   6.90612879e+00   6.98578899e+00   7.06544919e+00
#    7.14510939e+00   7.22476959e+00   7.30442980e+00   7.38409000e+00
#    7.46375020e+00   7.54341040e+00   7.62307060e+00   7.70273080e+00
#    7.78239100e+00   7.86205121e+00   7.94171141e+00   8.02137161e+00
#    8.10103181e+00   8.18069201e+00   8.26035221e+00   8.34001241e+00
#    8.41967262e+00   8.49933282e+00   8.57899302e+00   8.65865322e+00
#    8.73831342e+00   8.81797362e+00   8.89763382e+00   8.97729403e+00
#    9.05695423e+00   9.13661443e+00   9.21627463e+00   9.29593483e+00
#    9.37559503e+00   9.45525523e+00   9.53491544e+00   9.61457564e+00
#    9.69423584e+00   9.77389604e+00   9.85355624e+00   9.93321644e+00
#    1.00128766e+01   1.00925368e+01   1.01721970e+01   1.02518572e+01
#    1.03315175e+01   1.04111777e+01   1.04908379e+01   1.05704981e+01
#    1.06501583e+01   1.07298185e+01   1.08094787e+01   1.08891389e+01
#    1.09687991e+01   1.10484593e+01   1.11281195e+01   1.12077797e+01
#    1.12874399e+01   1.13671001e+01   1.14467603e+01   1.15264205e+01
#    1.16060807e+01   1.16857409e+01   1.17654011e+01   1.18450613e+01
#    1.19247215e+01   1.20043817e+01   1.20840419e+01   1.21637021e+01
#    1.22433623e+01   1.23230225e+01   1.24026827e+01   1.24823429e+01
#    1.25620031e+01   1.26416633e+01   1.27213235e+01   1.28009837e+01
#    1.28806439e+01   1.29603041e+01   1.30399643e+01   1.31196245e+01
#    1.31992847e+01   1.32789449e+01   1.33586051e+01   1.34382653e+01
#    1.35179255e+01   1.35975857e+01   1.36772459e+01   1.37569061e+01
#    1.38365663e+01   1.39162265e+01   1.39958867e+01   1.40755469e+01
#    1.41552071e+01   1.42348673e+01   1.43145275e+01   1.43941877e+01
#    1.44738479e+01   1.45535081e+01   1.46331683e+01   1.47128285e+01
#    1.47924887e+01   1.48721489e+01   1.49518091e+01   1.50314693e+01
#    1.51111295e+01   1.51907897e+01   1.52704499e+01   1.53501101e+01
#    1.54297703e+01   1.55094305e+01   1.55890907e+01   1.56687509e+01
#    1.57484111e+01   1.58280714e+01   1.59077316e+01   1.59873918e+01
#    1.60670520e+01   1.61467122e+01   1.62263724e+01   1.63060326e+01
#    1.63856928e+01   1.64653530e+01   1.65450132e+01   1.66246734e+01
#    1.67043336e+01   1.67839938e+01   1.68636540e+01   1.69433142e+01
#    1.70229744e+01   1.71026346e+01   1.71822948e+01   1.72619550e+01
#    1.73416152e+01   1.74212754e+01   1.75009356e+01   1.75805958e+01
#    1.76602560e+01   1.77399162e+01   1.78195764e+01   1.78992366e+01
#    1.79788968e+01   1.80585570e+01   1.81382172e+01   1.82178774e+01
#    1.82975376e+01   1.83771978e+01   1.84568580e+01   1.85365182e+01
#    1.86161784e+01   1.86958386e+01   1.87754988e+01   1.88551590e+01
#    1.89348192e+01   1.90144794e+01   1.90941396e+01   1.91737998e+01
#    1.92534600e+01   1.93331202e+01   1.94127804e+01   1.94924406e+01
#    1.95721008e+01   1.96517610e+01   1.97314212e+01   1.98110814e+01
#    1.98907416e+01   1.99704018e+01   2.00500620e+01   2.01297222e+01
#    2.02093824e+01   2.02890426e+01   2.03687028e+01   2.04483630e+01
#    2.05280232e+01   2.06076834e+01   2.06873436e+01   2.07670038e+01
#    2.08466640e+01   2.09263242e+01   2.10059844e+01   2.10856446e+01
#    2.11653048e+01   2.12449650e+01   2.13246253e+01   2.14042855e+01
#    2.14839457e+01   2.15636059e+01   2.16432661e+01   2.17229263e+01
#    2.18025865e+01   2.18822467e+01   2.19619069e+01   2.20415671e+01
#    2.21212273e+01   2.22008875e+01   2.22805477e+01   2.23602079e+01
#    2.24398681e+01   2.25195283e+01   2.25991885e+01   2.26788487e+01
#    2.27585089e+01   2.28381691e+01   2.29178293e+01   2.29974895e+01
#    2.30771497e+01   2.31568099e+01   2.32364701e+01   2.33161303e+01
#    2.33957905e+01   2.34754507e+01   2.35551109e+01   2.36347711e+01
#    2.37144313e+01   2.37940915e+01   2.38737517e+01   2.39534119e+01
#    2.40330721e+01   2.41127323e+01   2.41923925e+01   2.42720527e+01
#    2.43517129e+01   2.44313731e+01   2.45110333e+01   2.45906935e+01
#    2.46703537e+01   2.47500139e+01   2.48296741e+01   2.49093343e+01
#    2.49889945e+01   2.50686547e+01   2.51483149e+01   2.52279751e+01
#    2.53076353e+01   2.53872955e+01   2.54669557e+01   2.55466159e+01
#    2.56262761e+01   2.57059363e+01   2.57855965e+01   2.58652567e+01
#    2.59449169e+01   2.60245771e+01   2.61042373e+01   2.61838975e+01
#    2.62635577e+01   2.63432179e+01   2.64228781e+01   2.65025383e+01
#    2.65821985e+01   2.66618587e+01   2.67415189e+01   2.68211792e+01
#    2.69008394e+01   2.69804996e+01   2.70601598e+01   2.71398200e+01
#    2.72194802e+01   2.72991404e+01   2.73788006e+01   2.74584608e+01
#    2.75381210e+01   2.76177812e+01   2.76974414e+01   2.77771016e+01
#    2.78567618e+01   2.79364220e+01   2.80160822e+01   2.80957424e+01
#    2.81754026e+01   2.82550628e+01   2.83347230e+01   2.84143832e+01
#    2.84940434e+01   2.85737036e+01   2.86533638e+01   2.87330240e+01
#    2.88126842e+01   2.88923444e+01   2.89720046e+01   2.90516648e+01
#    2.91313250e+01   2.92109852e+01   2.92906454e+01   2.93703056e+01
#    2.94499658e+01   2.95296260e+01   2.96092862e+01   2.96889464e+01
#    2.97686066e+01   2.98482668e+01   2.99279270e+01   3.00075872e+01
#    3.00872474e+01   3.01669076e+01   3.02465678e+01   3.03262280e+01
#    3.04058882e+01   3.04855484e+01   3.05652086e+01   3.06448688e+01
#    3.07245290e+01   3.08041892e+01   3.08838494e+01   3.09635096e+01
#    3.10431698e+01   3.11228300e+01   3.12024902e+01   3.12821504e+01
#    3.13618106e+01   3.14414708e+01   3.15211310e+01   3.16007912e+01
#    3.16804514e+01   3.17601116e+01   3.18397718e+01   3.19194320e+01
#    3.19990922e+01   3.20787524e+01   3.21584126e+01   3.22380728e+01
#    3.23177331e+01   3.23973933e+01   3.24770535e+01   3.25567137e+01
#    3.26363739e+01   3.27160341e+01   3.27956943e+01   3.28753545e+01
#    3.29550147e+01   3.30346749e+01   3.31143351e+01   3.31939953e+01
#    3.32736555e+01   3.33533157e+01   3.34329759e+01   3.35126361e+01
#    3.35922963e+01   3.36719565e+01   3.37516167e+01   3.38312769e+01
#    3.39109371e+01   3.39905973e+01   3.40702575e+01   3.41499177e+01
#    3.42295779e+01   3.43092381e+01   3.43888983e+01   3.44685585e+01
#    3.45482187e+01   3.46278789e+01   3.47075391e+01   3.47871993e+01
#    3.48668595e+01   3.49465197e+01   3.50261799e+01   3.51058401e+01
#    3.51855003e+01   3.52651605e+01   3.53448207e+01   3.54244809e+01
#    3.55041411e+01   3.55838013e+01   3.56634615e+01   3.57431217e+01
#    3.58227819e+01   3.59024421e+01   3.59821023e+01   3.60617625e+01
#    3.61414227e+01   3.62210829e+01   3.63007431e+01   3.63804033e+01
#    3.64600635e+01   3.65397237e+01   3.66193839e+01   3.66990441e+01
#    3.67787043e+01   3.68583645e+01   3.69380247e+01   3.70176849e+01
#    3.70973451e+01   3.71770053e+01   3.72566655e+01   3.73363257e+01
#    3.74159859e+01   3.74956461e+01   3.75753063e+01   3.76549665e+01
#    3.77346267e+01   3.78142869e+01   3.78939472e+01   3.79736074e+01
#    3.80532676e+01   3.81329278e+01   3.82125880e+01   3.82922482e+01
#    3.83719084e+01   3.84515686e+01   3.85312288e+01   3.86108890e+01
#    3.86905492e+01   3.87702094e+01   3.88498696e+01   3.89295298e+01
#    3.90091900e+01   3.90888502e+01   3.91685104e+01   3.92481706e+01
#    3.93278308e+01   3.94074910e+01   3.94871512e+01   3.95668114e+01
#    3.96464716e+01   3.97261318e+01   3.98057920e+01   3.98854522e+01
#    3.99651124e+01   4.00447726e+01   4.01244328e+01   4.02040930e+01
#    4.02837532e+01   4.03634134e+01   4.04430736e+01   4.05227338e+01]

# %%
'''
Here I have plotted our spectrum, the raw baseline data(from previous cell) and the interpolation of the baseline.
'''
fig = figure(1,(12,8),dpi=72)
plt.plot(calEn,cts,'r-',linewidth=2,label="Pena Specimen")
plt.plot(low[0], low[1],'b-',linewidth=2,label="Baseline")
plt.plot(calEn, lowf(calEn),'g-',linewidth=2,label="Baseline Interpolated")
plt.plot(calEn,cts**3,'y-',linewidth=2,label="Pena Specimen^2")
plt.xlabel("Energy (keV)",fontsize=20)
plt.ylabel("Counts/s",fontsize=20)
plt.xlim(12,20.)
plt.ylim(0.,2.)
plt.legend(fontsize=20)
plt.show()

# %%
'''
This cell plots the difference between our data and the interpolated baseline
'''
fig = figure(2,(12,8),dpi=72)
plt.plot(calEn, cts-lowf(calEn),'y-',linewidth=2,label="Pena-Baseline")
plt.xlabel("Energy (keV)",fontsize=20)
plt.ylabel("Counts/s",fontsize=20)
plt.xlim(0.,30.)
plt.ylim(-.05, .05) #I used this line as a tool to decide threshhold
plt.legend(fontsize=20)
plt.show()

# %%
'''
Here I am making the difference data more accesible
'''
db = cts-lowf(calEn)
print db
# Out:
# [ -1.90517350e-02  -1.90517350e-02  -1.90517350e-02  -1.90517350e-02
#    2.15585422e-02   3.50953013e-02   7.52042171e-03   0.00000000e+00
#    1.50408434e-03   0.00000000e+00  -1.50408434e-03   3.50953013e-03
#    0.00000000e+00  -1.67642734e-02  -4.20516914e-02  -5.53064346e-02
#   -7.25720695e-02  -4.42138126e-02  -5.44603872e-02  -2.10885159e-02
#   -1.57928856e-02   2.10885159e-02   3.74140980e-02   6.22628247e-02
#    5.95366718e-02   5.93173262e-02   5.55884504e-02   4.03282614e-02
#    0.00000000e+00   8.35602412e-04   3.17528916e-03   2.50680724e-03
#    2.84104820e-03   2.87447230e-02   0.00000000e+00   1.24337639e-02
#    1.88511904e-02   2.12577254e-02   1.71465615e-02   0.00000000e+00
#    1.30353976e-02   0.00000000e+00   3.25884941e-02   4.01089158e-02
#    0.00000000e+00   2.21434639e-02   7.38672532e-02   1.10550199e-01
#    8.20561568e-02   2.84940422e-02   0.00000000e+00   5.21415905e-02
#    0.00000000e+00   2.67392772e-03   1.68791687e-02   0.00000000e+00
#    4.34751998e-02   4.48360380e-02   2.16158407e-01   3.09268390e-01
#    2.53474023e-01   1.04426427e-01   0.00000000e+00   6.15003375e-02
#    2.52351928e-01   0.00000000e+00   3.55966627e-02   4.46211688e-02
#    7.11933255e-02   4.46211688e-02   0.00000000e+00  -1.18894286e-01
#   -2.25755897e-01  -1.48617858e-01   2.03767617e-01   3.26529548e-01
#    1.44965081e-01   0.00000000e+00   1.06945967e+00   1.05332141e+01
#    5.05303819e+01   1.09690587e+02   1.07031923e+02   4.62263610e+01
#    9.14772955e+00   8.02122608e-01   0.00000000e+00   9.52398739e-01
#    5.63743345e+00   1.45740132e+01   1.77188656e+01   9.75605507e+00
#    2.42345589e+00   7.23840589e-02   0.00000000e+00   1.71549175e-01
#    8.79053737e-02  -6.79344761e-02  -1.09965277e-01  -6.12496568e-02
#    0.00000000e+00   5.41470363e-02   7.06919640e-02   5.41470363e-02
#    0.00000000e+00   3.54713224e-02   4.76293375e-03   5.13895483e-03
#    0.00000000e+00   1.83832531e-02   3.52624218e-02   0.00000000e+00
#    1.37038796e-02   2.18927832e-02   0.00000000e+00   9.77654822e-03
#    0.00000000e+00   8.27246388e-03   0.00000000e+00   8.02178315e-03
#    2.60707952e-02   0.00000000e+00   1.00272289e-02   0.00000000e+00
#    1.11302241e-02   1.01976918e-01   1.28649347e-01   2.34637157e-02
#    0.00000000e+00   1.62942470e-02   0.00000000e+00   1.15313133e-02
#    1.45394820e-02   0.00000000e+00   2.61961356e-02   1.12806326e-02
#    1.49155030e-02   0.00000000e+00   8.12205544e-03   5.71552050e-03
#    1.23334916e-02   4.41198073e-03   0.00000000e+00   4.51225302e-03
#    0.00000000e+00   4.76293375e-03   0.00000000e+00   8.02178315e-03
#    0.00000000e+00   1.01943494e-02   8.35602412e-03   0.00000000e+00
#    4.71279760e-03   6.41742652e-03   1.06288627e-02   1.33362145e-02
#    0.00000000e+00   1.99541856e-02   4.54233471e-02   7.44020387e-02
#    1.28448803e-01   1.72969699e-01   1.80891210e-01   1.31156155e-01
#    5.43475809e-02  -2.90789639e-03   0.00000000e+00   2.01977040e-02
#    4.08967695e-02   5.20699674e-02   6.72540570e-02   4.53373994e-02
#    2.99384407e-02   0.00000000e+00   4.62366668e-03   1.37595864e-02
#    4.94676628e-02   8.16662090e-02   7.72653697e-02   3.92733133e-02
#    1.28125703e-02  -2.11685944e-03   0.00000000e+00   4.26157230e-03
#    0.00000000e+00   3.63487049e-03   7.26974098e-03   4.38691266e-03
#    0.00000000e+00   1.77983314e-02   0.00000000e+00   3.81034700e-03
#    2.46669832e-02   2.40653495e-03   4.21143615e-03   0.00000000e+00
#    7.01906026e-03   0.00000000e+00   8.52314460e-03   0.00000000e+00
#    6.26701809e-03   0.00000000e+00   4.19890212e-03   2.38146687e-03
#    1.06539307e-03   1.12806326e-02   1.24713660e-02   1.11552922e-02
#    9.83921840e-03   0.00000000e+00   2.61163736e-02   3.71919037e-02
#    5.97987471e-02   9.29341810e-02   1.05012434e-01   9.95430364e-02
#    9.65804460e-02   8.81028797e-02   3.40014218e-02   2.30170482e-02
#    0.00000000e+00   4.28085543e-03   1.75862169e-02   8.35345303e-02
#    1.60512796e-01   2.26461109e-01   1.62556808e-01   1.13693350e-01
#    4.67808796e-02   1.79718796e-02   8.21461448e-03   2.96960242e-03
#    1.73548193e-03   3.46944695e-18   1.27847169e-02   0.00000000e+00
#    5.51497592e-03   8.02178315e-03   9.52586749e-03   3.50953013e-03
#    0.00000000e+00   7.82123857e-03   9.62613978e-03   5.91606507e-03
#    5.21415905e-03   0.00000000e+00   5.01361447e-04   5.51497592e-03
#    9.02450605e-03   6.01633736e-03   0.00000000e+00   1.27847169e-02
#    0.00000000e+00   1.28515651e-01   1.78818916e-02   0.00000000e+00
#    7.77110243e-03   0.00000000e+00   1.33696386e-03   2.67392772e-03
#    0.00000000e+00   7.85466267e-03   2.62379157e-02   5.41470363e-02
#    4.69608555e-02   3.17528916e-02   0.00000000e+00   5.01361447e-04
#    0.00000000e+00   1.30353976e-03   5.11388676e-03   7.42014942e-03
#    5.21415905e-03   0.00000000e+00   1.00272289e-02   0.00000000e+00
#    6.64303917e-03   8.27246388e-03   2.39400091e-02   2.90789639e-02
#    3.57220031e-02   3.58473435e-02   2.79509007e-02   1.00272289e-02
#    8.14712351e-03   7.26974098e-03   2.38146687e-03   0.00000000e+00
#    3.50953013e-03   0.00000000e+00   2.00544579e-03   3.00816868e-03
#    0.00000000e+00   5.64031628e-03   5.26429519e-03   5.89099700e-03
#    0.00000000e+00   7.26974098e-03   0.00000000e+00   4.26157230e-03
#    0.00000000e+00   6.51769881e-03   3.50953013e-03   0.00000000e+00
#    2.25612651e-03   2.50680724e-03   2.75748796e-03   0.00000000e+00
#    1.25340362e-04   7.26974098e-03   7.39508134e-03   0.00000000e+00
#   -1.60435663e-03   8.02178315e-04   5.21415905e-03   8.62341689e-03
#    0.00000000e+00   5.15686060e-03   1.23191670e-02   8.95288298e-03
#    1.36083821e-02   2.17734114e-02   1.59003202e-02  -3.46944695e-18
#    9.77654822e-03   0.00000000e+00  -3.34240965e-04   4.84649399e-03
#    0.00000000e+00   8.65987954e-04   7.74831327e-03   1.86415302e-02
#    2.40197711e-02   3.94252411e-02   4.98170965e-02   3.56422411e-02
#    1.74564940e-02   1.33088675e-02   6.15307230e-03   0.00000000e+00
#    2.50680724e-03   4.01089158e-03   0.00000000e+00   2.75748796e-03
#    0.00000000e+00   1.94277561e-03   3.38418977e-03   9.83921840e-03
#    9.77654822e-03   4.70026357e-03   5.64031628e-03   4.07356176e-03
#   -1.73472348e-18   6.68481929e-04   2.84104820e-03   0.00000000e+00
#    1.67120482e-03   2.33968675e-03   0.00000000e+00   5.09717471e-03
#    5.68209640e-03   1.32860783e-02   1.33696386e-03   4.17801206e-04
#    0.00000000e+00   2.25612651e-03   0.00000000e+00   5.01361447e-04
#    3.00816868e-03   0.00000000e+00   1.50408434e-03   0.00000000e+00
#    1.83832531e-03   1.16984338e-03   0.00000000e+00  -6.68481929e-04
#    4.67937351e-03   0.00000000e+00   1.50408434e-03   0.00000000e+00
#    6.01633736e-03   3.76021085e-02   5.61524821e-02   2.44724550e+01
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#   -1.10299518e-02  -1.10299518e-02  -1.10299518e-02  -1.10299518e-02
#    4.01089158e-03   7.52042171e-03  -1.10299518e-02  -1.10299518e-02]

# %%
'''
This code finds all local maxima and puts it into an array. It also smoothes out all data below the threshhold.
'''
peak = [[],[]]
for en in xrange(2,511):
    if db[en]<.05:
        db[en]=0
    if db[en]>db[en+1] and db[en]>db[en-1] and calEn[en]>0 and calEn[en]<30:
        peak[0].append(calEn[en])
        peak[1].append(cts[en])
print peak
# Out:
# [[1.6485554928213424, 3.5604003275591247, 3.8790411333487556, 4.5163227449280159, 4.9146237521650535, 5.2332645579546844, 5.7908859680865374, 6.2688471767709828, 6.9857889897976513, 7.3840899970346889, 7.9417114071665429, 9.8535562419043252, 12.721323494010999, 13.358605105590259, 13.916226515722112, 16.863653969276193, 17.739916185197675, 19.970401825725087, 20.767003840199166], [0.46325797703664301, 0.71845095356440414, 0.65878894137029109, 0.99971472533665173, 0.95158402642375373, 0.81070145981412522, 1.7918658116114308, 111.24107513954142, 18.729359575928434, 0.80719192968505982, 0.37451700091598739, 0.28577602479533171, 0.32087132608598651, 0.15291524133785295, 0.13987984371560974, 0.17647922934729257, 0.28176513321925689, 0.17347106066523646, 0.08673553033261823]]

# %%
'''
This cell plots the smooth peaks
'''
fig = figure(3,(12,8),dpi=72)
plt.plot(calEn, db,'y-',linewidth=2,label="Pena-Baseline")
plt.plot(calEn, db,'r.',linewidth=2,label="Pena-Baseline")
plt.xlabel("Energy (keV)",fontsize=20)
plt.ylabel("Counts/s",fontsize=20)
plt.xlim(10.,20)
plt.ylim(-1, .5)
plt.legend(fontsize=20)
plt.show()

# %%
def loadLines():
    xrays = [(2.31, 2.46), (3.31, 3.59), (3.69, 4.01), (4.09, 4.46), (4.51, 4.93), \
         (4.95, 5.43), (5.41, 5.43), (5.90, 6.49), (6.40, 7.06), \
         (6.93, 7.65), (7.48, 8.26), (8.05, 8.90), (8.64, 9.57), \
         (9.25, 10.26), (9.89, 10.98), (10.54, 11.73), (11.22, 12.50), \
         (11.92, 13.29), (12.65, 14.11), (13.39, 14.96), (14.16, 15.83), \
         (14.96, 16.74), (15.77, 17.67), (16.61, 18.62), (17.48, 19.61), \
         (18.41, 19.61), (19.28, 21.66), (20.21, 22.72), (21.18, 23.82), \
         (22.16, 24.94), (23.17, 26.09), (24.21, 27.27), (25.27, 28.48), \
         (26.36, 29.72), (27.47, 30.99), (28.61, 32.29), (29.80, 33.64), \
         (30.97, 34.98), (32.19, 36.38), (4.11, 4.42), (4.29, 4.62), \
         (4.47, 4.83), (8.40, 9.67), (9.19, 10.71), (9.71, 11.44), \
         (9.99, 11.82), (10.55, 12.61), (12.34, 15.23), (12.97, 16.20), \
         (13.61, 17.22), (14.28, 18.28), (14.62, 18.83), (11.72, 14.32)]
    elementsK = {}
    for i in xrange(11,56):
        try:
            elementsK[str(i)] = (nd.Ka["'" + str(pt.elements[i]) + "'"],nd.Kb1["'" + str(pt.elements[i]) + "'"])
            elementsK[str(pt.elements[i])] = (nd.Ka["'" + str(pt.elements[i]) + "'"],nd.Kb1["'" + str(pt.elements[i]) + "'"])
            elementsK[str(pt.elements[i].name)] = (nd.Ka["'" + str(pt.elements[i]) + "'"],nd.Kb1["'" + str(pt.elements[i]) + "'"])
        except KeyError:
            print str(pt.elements[i].name) + " has no K-line data."
    elementsL = {}
    for i in xrange(30,100):
        try:
            elementsL[str(i)] = (nd.La["'" + str(pt.elements[i]) + "'"],nd.Lb1["'" + str(pt.elements[i]) + "'"])
            elementsL[str(pt.elements[i])] = (nd.La["'" + str(pt.elements[i]) + "'"],nd.Lb1["'" + str(pt.elements[i]) + "'"])
            elementsL[str(pt.elements[i].name)] = (nd.La["'" + str(pt.elements[i]) + "'"],nd.Lb1["'" + str(pt.elements[i]) + "'"])
        except KeyError:
            print str(pt.elements[i].name) + " has no L-line data."
    elements = [('S K-a','S K-b'), ('K K-a','K K-b'), ('Ca K-a','Ca K-b'), ('Sc K-a','Sc K-b'), \
            ('Ti K-a','Ti K-b'), ('V K-a','V K-b'), ('Cr K-a','Cr K-b'), \
            ('Mn K-a','Mn K-b'), ('Fe K-a','Fe K-b'), ('Co K-a','Co K-b'), \
            ('Ni K-a','Ni K-b'), ('Cu K-a','Cu K-b'), ('Zn K-a','Zn K-b'), \
            ('Ga K-a','Ga K-b'), ('Ge K-a','Ge K-b'), ('As K-a','As K-b'), \
            ('Se K-a','Se K-b'), ('Br K-a','Br K-b'), ('Kr K-a','Kr K-b'), \
            ('Rb K-a','Rb K-b'), ('Sr K-a','Sr K-b'), ('Y K-a','Y K-b'), \
            ('Zr K-a','Zr K-b'), ('Nb K-a','Nb K-b'), ('Mo K-a','Mo K-b'), \
            ('Tc K-a','Tc K-b'), ('Ru K-a','Ru K-b'), ('Rh K-a','Rh K-b'), \
            ('Pd K-a','Pd K-b'), ('Ag K-a','Ag K-b'), ('Cd K-a','Cd K-b'), \
            ('In K-a','In K-b'), ('Sn K-a','Sn K-b'), ('Sb K-a','Sb K-b'), \
            ('Te K-a','Te K-b'), ('I K-a','I K-b'), ('Xe K-a','Xe K-b'), \
            ('Cs K-a','Cs K-b'), ('Ba K-a','Ba K-b'), ('Xe L-a','Xe L-b'), \
            ('Cs L-a','Cs L-b'), ('Ba L-a','Ba L-b'), ('W L-a','W L-b'), \
            ('Ir L-a','Ir L-b'), ('Au L-a','Au L-b'), ('Hg L-a','Hg L-b'), \
            ('Pb L-a','Pb L-b'), ('Ra L-a','Ra L-b'), ('Th L-a','Th L-b'), \
            ('U L-a','U L-b'), ('Pu L-a','Pu L-b'), ('Am L-a','Am L-b'), \
            ('Rn L-a','Rn L-b')]

    return elementsK, elementsL

    

"""    
    Ka = np.empty((2,41),dtype=float)
    Names = []
    count = 0
    for line in open('../Kseries.dat'):
        els = line.split()
        Ka[0,count] = els[1]
        Ka[1,count] = els[2]
        Names.append(els[0])
        count += 1
    return Names,Ka

def loadLLines():  
    La = np.empty((2,67),dtype=float)
    Names = []
    count = 0
    for line in open('../Lseries.dat'):
        els = line.split()
        La[0,count] = els[1]
        La[1,count] = els[2]
        Names.append(els[0])
        count += 1
    return Names,La
"""
# Out:
# "    \n    Ka = np.empty((2,41),dtype=float)\n    Names = []\n    count = 0\n    for line in open('../Kseries.dat'):\n        els = line.split()\n        Ka[0,count] = els[1]\n        Ka[1,count] = els[2]\n        Names.append(els[0])\n        count += 1\n    return Names,Ka\n\ndef loadLLines():  \n    La = np.empty((2,67),dtype=float)\n    Names = []\n    count = 0\n    for line in open('../Lseries.dat'):\n        els = line.split()\n        La[0,count] = els[1]\n        La[1,count] = els[2]\n        Names.append(els[0])\n        count += 1\n    return Names,La\n"

# %%
K={}
L={}
K,L = loadLines()
print K['35']
print L
# Out:
# phosphorus has no K-line data.
# sulfur has no K-line data.
# potassium has no K-line data.
# vanadium has no K-line data.
# yttrium has no K-line data.
# tellurium has no K-line data.
# iodine has no K-line data.
# xenon has no K-line data.
# cesium has no K-line data.
# yttrium has no L-line data.
# technetium has no L-line data.
# iodine has no L-line data.
# tungsten has no L-line data.
# uranium has no L-line data.
# curium has no L-line data.
# berkelium has no L-line data.
# einsteinium has no L-line data.
# (11.901055, 13.29156)
# {'Ru': (2.5564545, 2.683263), 'Yb': (7.3915500000000005, 8.40188), 'gold': (9.670745, 11.442450000000001), 'germanium': (1.18801, 1.2185), 'Re': (8.61941, 10.010040000000002), 'gadolinium': (6.04118, 6.7134), 'Rb': (1.6933555, 1.75218), '90': (12.8887175, 16.201556), 'Rn': (11.662585, 14.3158), 'Rh': (2.6944265, 2.8344389999999997), 'neodymium': (5.2189695, 5.721446), 'Pa': (13.20655, 16.702), 'Ba': (4.45862, 4.82758), '95': (14.514710000000001, 18.85218), 'selenium': (1.3791099999999998, 1.41924), 'Bi': (10.785, 13.02365), 'Br': (1.48046, 1.5259200000000002), 'americium': (14.514710000000001, 18.85218), '87': (11.963235000000001, 14.7704), 'barium': (4.45862, 4.82758), 'californium': (15.544, 20.656), 'radon': (11.662585, 14.3158), 'protactinium': (13.20655, 16.702), 'Os': (8.876465, 10.35542), 'silver': (2.98129, 3.150974), 'terbium': (6.255459999999999, 6.9778), '59': (5.023715, 5.4889), '58': (4.831615, 5.262930000000001), 'molybdenum': (2.291531, 2.3948310000000004), '55': (4.2794, 4.61983), '54': (4.103733, 4.417668), '57': (4.64264, 5.0421700000000005), '56': (4.45862, 4.82758), '51': (3.600057, 3.843615), '50': (3.4406835000000004, 3.662839), '52': (3.764085, 4.02963), 'Ge': (1.18801, 1.2185), '63': (5.831535000000001, 6.45572), 'Ga': (1.0979700000000001, 1.12476), 'indium': (3.2831520000000003, 3.487244), 'Ra': (12.268060000000002, 15.235899999999999), 'krypton': (1.5854110000000001, 1.636876), 'rubidium': (1.6933555, 1.75218), 'zinc': (1.01177, 1.03465), 'Pt': (9.402175, 11.07084), 'Pu': (14.18158, 18.29403), 'radium': (12.268060000000002, 15.235899999999999), 'Cf': (15.544, 20.656), 'Pb': (10.500595, 12.6138), 'Np': (13.85205, 17.75036), '88': (12.268060000000002, 15.235899999999999), '89': (12.576575, 15.7133), 'erbium': (6.9262065, 7.8101899999999995), 'Pd': (2.835975, 2.99025), 'astatine': (11.365935, 13.8762), '82': (10.500595, 12.6138), '83': (10.785, 13.02365), '80': (9.943295, 11.822700000000001), 'Xe': (4.103733, 4.417668), '86': (11.662585, 14.3158), 'Po': (11.07341, 13.4471), '84': (11.07341, 13.4471), 'Pm': (5.42025, 5.9615), 'antimony': (3.600057, 3.843615), 'europium': (5.831535000000001, 6.45572), 'lead': (10.500595, 12.6138), 'hafnium': (7.87189, 9.0228), 'lutetium': (7.630235000000001, 8.70913), 'Gd': (6.04118, 6.7134), 'Ho': (6.6990795, 7.52567), 'cerium': (4.831615, 5.262930000000001), 'osmium': (8.876465, 10.35542), 'Hf': (7.87189, 9.0228), 'rhodium': (2.6944265, 2.8344389999999997), 'mercury': (9.943295, 11.822700000000001), 'samarium': (5.6225115, 6.204073), 'Mo': (2.291531, 2.3948310000000004), 'thorium': (12.8887175, 16.201556), 'strontium': (1.8056775, 1.87174), 'bromine': (1.48046, 1.5259200000000002), 'Zn': (1.01177, 1.03465), '38': (1.8056775, 1.87174), 'ytterbium': (7.3915500000000005, 8.40188), '76': (8.876465, 10.35542), '33': (1.28201, 1.31699), '32': (1.18801, 1.2185), '31': (1.0979700000000001, 1.12476), '30': (1.01177, 1.03465), '37': (1.6933555, 1.75218), '36': (1.5854110000000001, 1.636876), '35': (1.48046, 1.5259200000000002), '34': (1.3791099999999998, 1.41924), 'tantalum': (8.117049999999999, 9.34319), 'cesium': (4.2794, 4.61983), 'Zr': (2.0413395000000003, 2.1243939999999997), 'Er': (6.9262065, 7.8101899999999995), 'Pr': (5.023715, 5.4889), 'Nb': (2.1644550000000002, 2.25738), 'Nd': (5.2189695, 5.721446), '60': (5.2189695, 5.721446), '61': (5.42025, 5.9615), '62': (5.6225115, 6.204073), 'praseodymium': (5.023715, 5.4889), '64': (6.04118, 6.7134), '65': (6.255459999999999, 6.9778), '66': (6.476495, 7.247800000000001), '67': (6.6990795, 7.52567), '68': (6.9262065, 7.8101899999999995), '69': (7.156914, 8.102265000000001), 'arsenic': (1.28201, 1.31699), 'platinum': (9.402175, 11.07084), 'Fr': (11.963235000000001, 14.7704), 'actinium': (12.576575, 15.7133), 'thulium': (7.156914, 8.102265000000001), 'ruthenium': (2.5564545, 2.683263), 'Sr': (1.8056775, 1.87174), 'Kr': (1.5854110000000001, 1.636876), 'Sn': (3.4406835000000004, 3.662839), 'Sm': (5.6225115, 6.204073), '91': (13.20655,  ...

# %%
'''
This cell guesses what the closest K-alpha line is to every peak. It is quite broad and needs fine-tuning.
I am no longer using it, see next cell.
'''
bestbetK = [[],[]]
bestbetL = [[],[]]
distbK = [[],[]]
distbL = [[],[]]
newel = False
for en in peak[0]:
    distance = 1000
    newel = True
    bestbetK[0].append(en)
    for ka in K.keys():
        dif = abs(K[ka][0]-en)
        if (dif < distance):
            if newel == False:
                del bestbetK[1][-1]
            distance = abs(K[ka][0]-en)
            bestbetK[1].append(ka)
            newel = False
for en in peak[0]:
    distance = 1000
    newel = True
    bestbetL[0].append(en)
    for la in L.keys():
        dif = abs(L[la][0]-en)
        if (dif < distance):
            if newel == False:
                del bestbetL[1][-1]
            distance = abs(L[la][0]-en)
            bestbetL[1].append(la)
            newel = False
for p in xrange((len(peak[0])-1)):
    if K[bestbetK[1][p]][1]-K[bestbetK[1][p]][0]<=(peak[0][p+1]-peak[0][p])+.1 and \
    K[bestbetK[1][p]][1]-K[bestbetK[1][p]][0]>=(peak[0][p+1]-peak[0][p])-.1:
        distbK[0].append(peak[0][p])
        distbK[1].append(bestbetK[1][p])
for p in xrange((len(peak[0])-1)):
    if L[bestbetL[1][p]][1]-L[bestbetL[1][p]][0]<=(peak[0][p+1]-peak[0][p])+.1 and \
    L[bestbetL[1][p]][1]-L[bestbetL[1][p]][0]>=(peak[0][p+1]-peak[0][p])-.1:
        distbL[0].append(peak[0][p])
        distbL[1].append(bestbetL[1][p])
print distbK,distbL
# Out:
# [[3.5604003275591247, 4.5163227449280159, 5.2332645579546844, 6.2688471767709828, 17.739916185197675], ['20', '22', '24', '26', 'molybdenum']] [[3.5604003275591247, 4.5163227449280159, 5.2332645579546844, 6.2688471767709828], ['51', 'Ba', 'neodymium', 'terbium']]

# %%
difference = [[],[],[]]#energy1, energy2, difference
difteq = [[],[],[],[],[],[]]#(energy1K, energy2K),(energy1L, energy2L),elementK,elementL, differeence
newel = False
kgot = False
d = .5
pos = .2
def peakfind(d,pos,shift):
    difference[:]=[[],[],[]]
    difteq[:]=[[],[],[],[],[],[]]
    for i in xrange(len(peak[0])):
        for p in xrange(i,len(peak[0])-1):
            difference[0].append(peak[0][i])
            difference[1].append(peak[0][p+1])
            difference[2].append(peak[0][p+1]-peak[0][i])
    for j in xrange(len(difference[2])):
        distance = 1000
        newel = True
        kgot = False
        for ka in K.keys():
            if abs(difference[2][j]-(K[ka][1]-K[ka][0])) < distance and abs(K[ka][0]-difference[0][j]) <= abs(K[ka][1]-difference[1][j])+d and \
            abs(K[ka][0]-difference[0][j]) >= abs(K[ka][1]-difference[1][j])-d and K[ka][0]-difference[0][j]<shift+pos and \
            K[ka][0]-difference[0][j]>shift-pos:
                #print ka,j,difference[2][j]-(K[ka][1]-K[ka][0]), "k"
                if newel == False:
                    del difteq[2][-1]
                    del difteq[0][-1]
                    del difteq[4][-1]
                distance = abs(difference[2][j]-(K[ka][1]-K[ka][0]))
                difteq[2].append(ka)
                difteq[4].append(distance)
                difteq[0].append((difference[0][j],difference[1][j]))
                kgot = True
                newel = False
                #print difteq[2]
        distance = 1000
        newel = True
        for la in L.keys():
            if abs(difference[2][j]-(L[la][1]-L[la][0]))<distance and abs(L[la][0]-difference[0][j]) <= abs(L[la][1]-difference[1][j])+d and \
            abs(L[la][0]-difference[0][j]) >= abs(L[la][1]-difference[1][j])-d and L[la][0]-difference[0][j]<shift+pos and \
            L[la][0]-difference[0][j]>shift-pos:
                #print la, j,difference[2][j]-(L[la][1]-L[la][0]), "l"
                if newel == False:
                    del difteq[3][-1]
                    del difteq[1][-1]
                    del difteq[5][-1]
                distance = abs(difference[2][j]-(L[la][1]-L[la][0]))
                if kgot == True and abs(difference[2][j]-(K[difteq[2][-1]][1]-K[difteq[2][-1]][0])) > abs(difference[2][j]-(L[la][1]-L[la][0])):
                    difteq[3].append(la)
                    difteq[5].append(distance)
                    difteq[1].append((difference[0][j],difference[1][j]))
                    del difteq[2][-1]
                    del difteq[0][-1]
                    del difteq[4][-1]
                    #print difteq[2]
                    newel = False
                if kgot == False:
                    difteq[3].append(la)
                    difteq[5].append(distance)
                    difteq[1].append((difference[0][j],difference[1][j]))
                    newel = False
                #print difteq[3]
    #print difteq
    #print len(difteq[2]), len(difteq[3]), len(difteq[0])
    i=0
    while i+1 < len(difteq[0]):
        if difteq[4][i+1]<difteq[4][i] and difteq[0][i+1][0]==difteq[0][i][0]:
            del difteq[2][i]
            del difteq[4][i]
            del difteq[0][i]
        elif difteq[4][i+1]>difteq[4][i] and difteq[0][i+1][0]==difteq[0][i][0]:
            del difteq[2][i+1]
            del difteq[4][i+1]
            del difteq[0][i+1]
        else:
            i += 1
    #print difteq
    j=0
    while j+1 < len(difteq[1]):
        if difteq[5][j+1]<difteq[5][j] and difteq[1][j+1][0]==difteq[1][j][0]:
            del difteq[3][j]
            del difteq[5][j]
            del difteq[1][j]
        elif difteq[5][j+1]>difteq[5][j] and difteq[1][j+1][0]==difteq[1][j][0]:
            del difteq[3][j+1]
            del difteq[5][j+1]
            del difteq[1][j+1]
        else:
            j += 1
    #print difteq

# %%
#create an interact that lets you slide through the dictionary, 
#plotting a vertical line at the line pairs for each element, printing the element name as a label
#Hey Patrick, try defining a distance kb-ka for each kline and do the same for the peaks. ask klay about all the peaks being
#equally proportional

def identify(elnum=25, d=.2, pos=.1, shift=.12):
    try:
        peakfind(d, pos, shift)
        data = np.loadtxt("Calibrated-Pena-data.txt")
        fig = figure(2,(24,16),dpi=72)
        fig.clear()
        plt.plot(calEn, db,'g-')
        plt.xlim(3.,30.)
    #    plt.ylim(0.,ct1[0:380].max()*1.05)
    
        #print xrays[elnum][0],xrays[elnum][1]
    
        label1 = r"%s K-$\alpha$"%pt.elements[elnum]
        label2 = r"%s K-$\beta$"%pt.elements[elnum]
        for ka in difteq[2]:
            plt.plot([K[ka][0],K[ka][0]],[1.e-3,cts[0:380].max()*1.05],'-',label=r"%s K-$\alpha$ %0.3f"%(ka,difteq[4][difteq[2].index(ka)]))
            plt.plot([K[ka][1],K[ka][1]],[1.e-3,cts[0:380].max()*1.05],'--',label=r"%s K-$\beta$ %0.3f"%(ka,difteq[4][difteq[2].index(ka)]))
        for la in difteq[3]:
            plt.plot([L[la][0],L[la][0]],[1.e-3,cts[0:380].max()*1.05],'-',label=r"%s L-$\alpha$ %0.3f"%(la,difteq[5][difteq[3].index(la)]))
            plt.plot([L[la][1],L[la][1]],[1.e-3,cts[0:380].max()*1.05],'--',label=r"%s L-$\beta$ %0.3f"%(la,difteq[5][difteq[3].index(la)]))
        '''
        for ka in distbK[1]:
            plt.plot([K[ka][0],K[ka][0]],[1.e-3,cts[0:380].max()*1.05],'b-',label=r"%s K-$\alpha$"%ka)
            plt.plot([K[ka][1],K[ka][1]],[1.e-3,cts[0:380].max()*1.05],'b--',label=r"%s K-$\beta$"%ka)
        for la in distbL[1]:
            plt.plot([L[la][0],L[la][0]],[1.e-3,cts[0:380].max()*1.05],'r-',label=r"%s L-$\alpha$"%la)
            plt.plot([L[la][1],L[la][1]],[1.e-3,cts[0:380].max()*1.05],'r--',label=r"%s L-$\beta$"%la)
        '''
        plt.legend(fontsize=20)
        plt.xlabel("Energy (keV)",fontsize=20)
        plt.ylabel("Counts/s",fontsize=20)
        plt.ylim(-.2, 2)
        plt.show()
    except KeyError:
        print str(pt.elements[elnum].name) + " has no K-line" 
    
v = interact(identify,elnum=(11,54), d=(0.00,.20,.01),pos=(0,.20,.01),shift=(0,.75,.01))
